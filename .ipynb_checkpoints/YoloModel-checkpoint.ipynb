# %%
import torch
import ultralytics

print("--- SYSTEM DIAGNOSTICS ---")
print(f"PyTorch Version: {torch.__version__}")
print(f"Ultralytics Version: {ultralytics.__version__}\n")

cuda_available = torch.cuda.is_available()
print(f"CUDA Available: {cuda_available}")

if cuda_available:
    print(f"GPU Device Name: {torch.cuda.get_device_name(0)}")
    print(f"Number of GPUs: {torch.cuda.device_count()}")
else:
    print("\n⚠️ WARNING: CUDA is NOT available!")
    print("Your models will train on the CPU, which is extremely slow.")
# Out:
# --- SYSTEM DIAGNOSTICS ---
# PyTorch Version: 2.7.1+cu118
# Ultralytics Version: 8.4.37
#
# CUDA Available: True
# GPU Device Name: NVIDIA GeForce RTX 3060
# Number of GPUs: 1

# %%
import os

# --- UPDATE THIS TO YOUR MAIN RAF-DB FOLDER ---
# (The folder that contains the 'train' and 'test' subfolders)
DATASET_DIR = r'C:\Users\User\Desktop\AiAssignment\Ai-Assignment\RAF-DB'
# ----------------------------------------------

emotion_map = {
    '1': 'surprise', '2': 'fear', '3': 'disgust', 
    '4': 'happy', '5': 'sad', '6': 'angry', '7': 'neutral'
}

print("Renaming folders...")

for split in ['train', 'test']:
    split_dir = os.path.join(DATASET_DIR, split)
    
    # Check if the train/test folder exists
    if not os.path.exists(split_dir):
        print(f"⚠️ Could not find folder: {split_dir}")
        continue

    for folder_num, emotion_name in emotion_map.items():
        old_path = os.path.join(split_dir, folder_num)
        new_path = os.path.join(split_dir, emotion_name)
        
        # If the numbered folder exists, rename it
        if os.path.exists(old_path):
            os.rename(old_path, new_path)
            print(f"✅ Renamed: {split}/{folder_num} -> {split}/{emotion_name}")
        elif os.path.exists(new_path):
            print(f"ℹ️ Already named correctly: {split}/{emotion_name}")

print("\n🚀 Phase 1 Complete! Move straight to the Phase 2 Preprocessing script.")
# Out:
# Renaming folders...
# ℹ️ Already named correctly: train/surprise
# ℹ️ Already named correctly: train/fear
# ℹ️ Already named correctly: train/disgust
# ℹ️ Already named correctly: train/happy
# ℹ️ Already named correctly: train/sad
# ℹ️ Already named correctly: train/angry
# ℹ️ Already named correctly: train/neutral
# ℹ️ Already named correctly: test/surprise
# ℹ️ Already named correctly: test/fear
# ℹ️ Already named correctly: test/disgust
# ℹ️ Already named correctly: test/happy
# ℹ️ Already named correctly: test/sad
# ℹ️ Already named correctly: test/angry
# ℹ️ Already named correctly: test/neutral
#
# 🚀 Phase 1 Complete! Move straight to the Phase 2 Preprocessing script.

# %%
from ultralytics import YOLO
import os

DATA_PATH = r"C:\Users\User\Desktop\YoloTraining\RAF-DB"

# 1. Load the MEDIUM classification model
model = YOLO('yolov8m-cls.pt') 

# 2. Start Training (Removed image_weights)
results = model.train(
    data=DATA_PATH, 
    epochs=50, 
    imgsz=224, 
    batch=16,
    # image_weights=True,  <-- REMOVED because it's for detection only
    project='Emotion_Project',
    name='YOLO_Medium_Raw_Run'
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.38 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.37  Python-3.10.20 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=C:\Users\User\Desktop\YoloTraining\RAF-DB, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8m-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=YOLO_Medium_Raw_Run, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=Emotion_Project, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\User\Desktop\YoloTraining\runs\classify\Emotion_Project\YOLO_Medium_Raw_Run, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: C:\Users\User\Desktop\YoloTraining\RAF-DB\train... found 12271 images in 7 classes
# val: None...
# test: C:\Users\User\Desktop\YoloTraining\RAF-DB\test... found 3068 images in 7 classes
# Overriding model.yaml nc=1000 with nc=7
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   2655744  ultralytics.nn.modules.conv.Conv             [384, 768, 3, 2]
#   8                  -1  2   7084032  ultralytics.nn.modules.block.C2f             [768, 768, 2, True]
#   9                  -1  1    994567  ultralytics.nn.modules.head.Classify         [768, 7]
# YOLOv8m-cls summary: 80 layers, 15,781,303 parameters, 15,781,303 gradients, 41.9 GFLOPs
# Transferred 228/230 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 12.7MB/s 0.4s.4s<0.0s.4s
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 0.70.2 MB/s, size: 2.8 KB)
# train: Scanning C:\Users\User\Desktop\YoloTraining\RAF-DB\train... 12271 images, 0 corrupt: 100% ━━━━━━━━━━━━ 12271/12271 1.8Kit/s 6.8s0.1s
# train: New cache created: C:\Users\User\Desktop\YoloTraining\RAF-DB\train.cache
# val: Fast image access  (ping: 0.10.0 ms, read: 0.50.1 MB/s, size: 2.6 KB)
# val: Scanning C:\Users\User\Desktop\YoloTraining\RAF-DB\test... 3068 images, 0 corrupt: 100% ━━━━━━━━━━━━ 3068/3068 1.7Kit/s 1.8s0.1s
# val: New cache created: C:\Users\User\Desktop\YoloTraining\RAF-DB\test.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000909, momentum=0.9) with parameter groups 38 weight(decay=0.0), 39 weight(decay=0.0005), 39 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 8 dataloader workers
# Logging results to C:\Users\User\Desktop\YoloTraining\runs\classify\Emotion_Project\YOLO_Medium_Raw_Run
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/50      0.85G      1.308         15        224: 100% ━━━━━━━━━━━━ 767/767 21.7it/s 35.4s<0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 96/96 43.1it/s 2.2s0.1s
#                    all      0.713      0.983
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/50         1G     0.8712         15        224: 100% ━━━━━━━━━━━━ 767/767 25.0it/s 30.6s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 96/96 47.3it/s 2.0s0.0s
#                    all      0.746      0.989
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/50      1.08G     0.7859         15        224: 100% ━━━━━━━━━━━━ 767/767 26.1it/s 29.3s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 96/96 47.3it/s 2.0s0.0s
#                    all      0.784      0.991
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/50      1.21G     0.7397         15        224: 100% ━━━━━━━━━━━━ 767/767 26.6it/s 28.8s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 96/96 47.1it/s 2.0s0.0s
#                    all      0.804      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/50      1.33G     0.6623         15        224: 100% ━━━━━━━━━━━━ 767/767 26.6it/s 28.9s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 96/96 46.9it/s 2.0s0.0s
#                    all      0.795      0.992
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/50      1.46G     0.6124         15        224: 100% ━━━━━━━━━━━━ 767/767 26.5it/s 29.0s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 96/96 47.3it/s 2.0s0.0s
#                    all      0.808      0.995
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/50      1.58G     0.5577         15        224: 100% ━━━━━━━━━━━━ 767/767 25.8it/s 29.7s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 96/96 44.6it/s 2.2s0.0s
#                    all       0.82      0.994
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/50       1.7G     0.5205         15        224: 100% ━━━━━━━━━━━━ 767/767 26.4it/s 29.1s<0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 96/96 47.0it/s 2.0s0.0s
#                    all      0.826      0.995
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/50      1.83G      0.499         15        224: 100% ━━━━━━━━━━━━ 767/767 26.5it/s 28.9s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 96/96 47.2it/s 2.0s0.0s
#                    all      0.835      0.994
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/50      1.94G     0.4678         15        224: 100% ━━━━━━━━━━━━ 767/767 26.3it/s 29.1s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 96/96 47.3it/s 2.0s0.0s
#                    all      0.835      0.994
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/50      2.06G     0.4463         15        224: 100% ━━━━━━━━━━━━ 767/767 26.5it/s 29.0s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 96/96 46.9it/s 2.0s0.0s
#                    all      0.824      0.995
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/50      2.18G     0.4171         15        224: 100% ━━━━━━━━━━━━ 767/767 26.7it/s 28.8s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 96/96 47.4it/s 2.0s0.0s
#                    all      0.841      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/50      2.31G     0.4107         15        224: 100% ━━━━━━━━━━━━ 767/767 26.8it/s 28.6s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 96/96 47.0it/s 2.0s0.0s
#                    all      0.848      0.997
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/50      2.43G     0.3871         15        224: 100% ━━━━━━━━━━━━ 767/767 26.5it/s 29.0s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 96/96 45.5it/s 2.1s0.0s
#                    all      0.844      0.994
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/50
/s 29.3s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 96/96 46.5it/s 2.1s0.0s
#                    all      0.867      0.995
#
#       Epoch    GPU_mem       loss  Instances       Size
#       39/50      5.47G     0.1082         15        224: 100% ━━━━━━━━━━━━ 767/767 26.1it/s 29.4s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 96/96 46.3it/s 2.1s0.0s
#                    all      0.866      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#       40/50      5.58G     0.1091         15        224: 100% ━━━━━━━━━━━━ 767/767 26.1it/s 29.4s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 96/96 46.2it/s 2.1s0.0s
#                    all      0.869      0.997
#
#       Epoch    GPU_mem       loss  Instances       Size
#       41/50      5.73G     0.0941         15        224: 100% ━━━━━━━━━━━━ 767/767 25.3it/s 30.3s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 96/96 45.2it/s 2.1s0.0s
#                    all      0.872      0.995
#
#       Epoch    GPU_mem       loss  Instances       Size
#       42/50      5.83G    0.08894         15        224: 100% ━━━━━━━━━━━━ 767/767 25.7it/s 29.9s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 96/96 45.4it/s 2.1s0.0s
#                    all      0.871      0.995
#
#       Epoch    GPU_mem       loss  Instances       Size
#       43/50      5.95G    0.08705         15        224: 100% ━━━━━━━━━━━━ 767/767 25.7it/s 29.9s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 96/96 45.5it/s 2.1s0.0s
#                    all      0.871      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#       44/50      1.18G    0.08624         15        224: 100% ━━━━━━━━━━━━ 767/767 25.6it/s 30.0s<0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 96/96 47.1it/s 2.0s0.0s
#                    all       0.87      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#       45/50      1.18G    0.08328         15        224: 100% ━━━━━━━━━━━━ 767/767 26.0it/s 29.5s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 96/96 46.2it/s 2.1s0.0s
#                    all      0.869      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#       46/50      1.22G    0.07226         15        224: 100% ━━━━━━━━━━━━ 767/767 26.1it/s 29.4s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 96/96 46.3it/s 2.1s0.0s
#                    all      0.869      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#       47/50      1.32G    0.07048         15        224: 100% ━━━━━━━━━━━━ 767/767 26.2it/s 29.3s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 96/96 46.3it/s 2.1s0.0s
#                    all      0.871      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#       48/50      1.42G    0.06946         15        224: 100% ━━━━━━━━━━━━ 767/767 26.2it/s 29.3s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 96/96 46.3it/s 2.1s0.0s
#                    all       0.87      0.996
#
#       Epoch    GPU_mem       loss  Instances       Size
#       49/50      1.51G    0.06813         15        224: 100% ━━━━━━━━━━━━ 767/767 26.2it/s 29.3s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 96/96 46.3it/s 2.1s0.0s
#                    all      0.868      0.994
#
#       Epoch    GPU_mem       loss  Instances       Size
#       50/50      1.62G    0.06171         15        224: 100% ━━━━━━━━━━━━ 767/767 26.2it/s 29.3s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 96/96 46.4it/s 2.1s0.0s
#                    all      0.867      0.995
#
# 50 epochs completed in 0.451 hours.
# Optimizer stripped from C:\Users\User\Desktop\YoloTraining\runs\classify\Emotion_Project\YOLO_Medium_Raw_Run\weights\last.pt, 31.7MB
# Optimizer stripped from C:\Users\User\Desktop\YoloTraining\runs\classify\Emotion_Project\YOLO_Medium_Raw_Run\weights\best.pt, 31.7MB
#
# Validating C:\Users\User\Desktop\YoloTraining\runs\classify\Emotion_Project\YOLO_Medium_Raw_Run\weights\best.pt...
# Ultralytics 8.4.37  Python-3.10.20 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# YOLOv8m-cls summary (fused): 42 layers, 15,771,623 parameters, 0 gradients, 41.6 GFLOPs
# WARNING Dataset 'split=val' not found, using 'split=test' instead.
# train: C:\Users\User\Desktop\YoloTraining\RAF-DB\train... found 12271 images in 7 classes
# val: C:\Users\User\Desktop\YoloTraining\RAF-DB\test... found 3068 images in 7 classes
# test: C:\Users\User\Desktop\YoloTraining\RAF-DB\test... found 3068 images in 7 classes
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 96/96 47.3it/s 2.0s0.0s
#                    all      0.874      0.996
# Speed: 0.0ms preprocess, 0.6ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to C:\Users\User\Desktop\YoloTraining\runs\classify\Emotion_Project\YOLO_Medium_Raw_Run

# %%
import os
from ultralytics import YOLO
from sklearn.metrics import classification_report

# 1. Load your freshly trained model
# Make sure this points to the "best.pt" file YOLO just generated
model_path = r"C:\Users\User\Desktop\YoloTraining\runs\classify\Emotion_Project\YOLO_Medium_Raw_Run\weights\best.pt"
model = YOLO(model_path)

# 2. Point to your validation folder
val_dir = r"C:\Users\User\Desktop\YoloTraining\RAF-DB\test"

# YOLO automatically saved your class names inside the model
class_names = model.names # Looks like {0: 'angry', 1: 'disgust', ...}
target_names = [class_names[i] for i in range(len(class_names))]

y_true = []
y_pred = []

print("Running YOLO on validation images... (This will take about 15-30 seconds)")

# 3. Loop through the validation images and make predictions
for class_id, class_name in class_names.items():
    folder_path = os.path.join(val_dir, class_name)
    if not os.path.isdir(folder_path): continue
    
    for img_name in os.listdir(folder_path):
        img_path = os.path.join(folder_path, img_name)
        
        # Make a prediction (verbose=False stops it from spamming your console)
        results = model(img_path, verbose=False)
        
        # Extract the highest probability guess
        pred_class_id = results[0].probs.top1
        
        # Record the true answer and YOLO's guess
        y_true.append(class_id)
        y_pred.append(pred_class_id)

# 4. Print the final table!
print("\n" + "="*55)
print(" YOLOv8 CLASSIFICATION REPORT (BASELINE) ")
print("="*55)
report = classification_report(y_true, y_pred, target_names=target_names, digits=2)
print(report)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 14
#      11 val_dir = r"C:\Users\User\Desktop\YoloTraining\RAF-DB\test"
#      13 # YOLO automatically saved your class names inside the model
# ---> 14 class_names = model.names # Looks like {0: 'angry', 1: 'disgust', ...}
#      15 target_names = [class_names[i] for i in range(len(class_names))]
#      17 y_true = []
#
# File ~\anaconda3\envs\fer-env\lib\site-packages\ultralytics\engine\model.py:897, in Model.names(self)
#     895 if not self.predictor:  # export formats will not have predictor defined until predict() is called
#     896     predictor = self._smart_load("predictor")(overrides=self.overrides, _callbacks=self.callbacks)
# --> 897     predictor.setup_model(model=self.model, verbose=False)  # do not mess with self.predictor.model args
#     898     return predictor.model.names
#     899 return self.predictor.model.names
#
# File ~\anaconda3\envs\fer-env\lib\site-packages\ultralytics\engine\predictor.py:400, in BasePredictor.setup_model(self, model, verbose)
#     398     if model.end2end:
#     399         model.set_head_attr(max_det=self.args.max_det, agnostic_nms=self.args.agnostic_nms)
# --> 400 self.model = AutoBackend(
#     401     model=model or self.args.model,
#     402     device=select_device(self.args.device, verbose=verbose),
#     403     dnn=self.args.dnn,
#     404     data=self.args.data,
#     405     fp16=self.args.half,
#     406     fuse=True,
#     407     verbose=verbose,
#     408 )
#     410 self.device = self.model.device  # update device
#     411 self.args.half = self.model.fp16  # update half
#
# File ~\anaconda3\envs\fer-env\lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~\anaconda3\envs\fer-env\lib\site-packages\ultralytics\nn\autobackend.py:204, in AutoBackend.__init__(self, model, device, dnn, data, fp16, fuse, verbose)
#     201 if format not in self._BACKEND_MAP:
#     202     from ultralytics.engine.exporter import export_formats
# --> 204     raise TypeError(
#     205         f"model='{model}' is not a supported model format. "
#     206         f"Ultralytics supports: {export_formats()['Format']}\n"
#     207         f"See https://docs.ultralytics.com/modes/predict for help."
#     208     )
#     209 if format == "pt":
#     210     backend_kwargs["fuse"] = fuse
#
# TypeError: model='C:\Users\User\Desktop\YoloTraining\runs\classify\Emotion_Project\YOLO_Medium_Raw_Run\weights' is not a supported model format. Ultralytics supports: ('PyTorch', 'TorchScript', 'ONNX', 'OpenVINO', 'TensorRT', 'CoreML', 'TensorFlow SavedModel', 'TensorFlow GraphDef', 'TensorFlow Lite', 'TensorFlow Edge TPU', 'TensorFlow.js', 'PaddlePaddle', 'MNN', 'NCNN', 'IMX', 'RKNN', 'ExecuTorch', 'Axelera AI')
# See https://docs.ultralytics.com/modes/predict for help.
