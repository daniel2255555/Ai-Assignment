# %%
import torch
import ultralytics

print("--- SYSTEM DIAGNOSTICS ---")
print(f"PyTorch Version: {torch.__version__}")
print(f"Ultralytics Version: {ultralytics.__version__}\n")

cuda_available = torch.cuda.is_available()
print(f"CUDA Available: {cuda_available}")

if cuda_available:
    print(f"GPU Device Name: {torch.cuda.get_device_name(0)}")
    print(f"Number of GPUs: {torch.cuda.device_count()}")
else:
    print("\n⚠️ WARNING: CUDA is NOT available!")
    print("Your models will train on the CPU, which is extremely slow.")
# Out:
# --- SYSTEM DIAGNOSTICS ---
# PyTorch Version: 2.7.1+cu118
# Ultralytics Version: 8.4.37
#
# CUDA Available: True
# GPU Device Name: NVIDIA GeForce RTX 3060
# Number of GPUs: 1

# %%
import os

# --- UPDATE THIS TO YOUR MAIN RAF-DB FOLDER ---
# (The folder that contains the 'train' and 'test' subfolders)
DATASET_DIR = r'C:\Users\User\Desktop\AiAssignment\Ai-Assignment\RAF-DB'
# ----------------------------------------------

emotion_map = {
    '1': 'surprise', '2': 'fear', '3': 'disgust', 
    '4': 'happy', '5': 'sad', '6': 'angry', '7': 'neutral'
}

print("Renaming folders...")

for split in ['train', 'test']:
    split_dir = os.path.join(DATASET_DIR, split)
    
    # Check if the train/test folder exists
    if not os.path.exists(split_dir):
        print(f"⚠️ Could not find folder: {split_dir}")
        continue

    for folder_num, emotion_name in emotion_map.items():
        old_path = os.path.join(split_dir, folder_num)
        new_path = os.path.join(split_dir, emotion_name)
        
        # If the numbered folder exists, rename it
        if os.path.exists(old_path):
            os.rename(old_path, new_path)
            print(f"✅ Renamed: {split}/{folder_num} -> {split}/{emotion_name}")
        elif os.path.exists(new_path):
            print(f"ℹ️ Already named correctly: {split}/{emotion_name}")

print("\n🚀 Phase 1 Complete! Move straight to the Phase 2 Preprocessing script.")
# Out:
# Renaming folders...
# ✅ Renamed: train/1 -> train/surprise
# ✅ Renamed: train/2 -> train/fear
# ✅ Renamed: train/3 -> train/disgust
# ✅ Renamed: train/4 -> train/happy
# ✅ Renamed: train/5 -> train/sad
# ✅ Renamed: train/6 -> train/angry
# ✅ Renamed: train/7 -> train/neutral
# ✅ Renamed: test/1 -> test/surprise
# ✅ Renamed: test/2 -> test/fear
# ✅ Renamed: test/3 -> test/disgust
# ✅ Renamed: test/4 -> test/happy
# ✅ Renamed: test/5 -> test/sad
# ✅ Renamed: test/6 -> test/angry
# ✅ Renamed: test/7 -> test/neutral
#
# 🚀 Phase 1 Complete! Move straight to the Phase 2 Preprocessing script.

# %%
import os
import cv2
import numpy as np
import glob

# --- UPDATE THIS PATH TO YOUR NEW RAF-DB TRAIN FOLDER ---
TRAIN_DIR = r'C:\Users\User\Desktop\AiAssignment\Ai-Assignment\RAF-DB\train'
# --------------------------------------------------------

def preprocess_and_augment(img):
    """Applies noise reduction and random augmentation."""
    # 1. Noise Reduction (Gaussian Blur)
    blurred = cv2.GaussianBlur(img, (3, 3), 0)
    
    # 2. Random Horizontal Flip
    if np.random.rand() > 0.5:
        blurred = cv2.flip(blurred, 1)
        
    # 3. Random Brightness (Simulates different lighting) safely
    value = np.random.randint(-20, 20)
    
    # Cast to int32 to safely do math beyond the 0-255 limits
    blurred_int = blurred.astype(np.int32)
    blurred_int = blurred_int + value
    
    # Force everything back into the 0-255 range
    blurred_clipped = np.clip(blurred_int, 0, 255)
    
    return blurred_clipped.astype(np.uint8)

emotions = os.listdir(TRAIN_DIR)
class_counts = {}

# Step 1: Find the target count (the size of the largest class)
for emotion in emotions:
    folder_path = os.path.join(TRAIN_DIR, emotion)
    if os.path.isdir(folder_path):
        class_counts[emotion] = len(glob.glob(os.path.join(folder_path, '*.jpg')))

TARGET_COUNT = max(class_counts.values())
print(f"🎯 Target balance count set to: {TARGET_COUNT} images per class")

# Step 2: Augment minority classes
for emotion in emotions:
    folder_path = os.path.join(TRAIN_DIR, emotion)
    if not os.path.isdir(folder_path): continue
        
    images = glob.glob(os.path.join(folder_path, '*.jpg'))
    current_count = len(images)
    shortfall = TARGET_COUNT - current_count
    
    if shortfall > 0:
        print(f" -> {emotion.upper()}: Generating {shortfall} synthetic images...")
        generated = 0
        while generated < shortfall:
            random_img_path = np.random.choice(images)
            img = cv2.imread(random_img_path, cv2.IMREAD_GRAYSCALE)
            
            if img is None: continue
            
            # Ensure 100x100 resolution
            img = cv2.resize(img, (100, 100))
            final_img = preprocess_and_augment(img)
            
            new_filename = f"aug_{generated}_{os.path.basename(random_img_path)}"
            cv2.imwrite(os.path.join(folder_path, new_filename), final_img)
            generated += 1
            
    # Step 3: Standardize the original images (Grayscale & 100x100)
    print(f" -> {emotion.upper()}: Standardizing original images...")
    for img_path in images:
        img = cv2.imread(img_path)
        if img is not None:
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            resized = cv2.resize(gray, (100, 100))
            cv2.imwrite(img_path, resized)

print("\n✅ RAF-DB Preprocessing Complete! Ready for Training.")
# Out:
# 🎯 Target balance count set to: 4772 images per class
#  -> ANGRY: Generating 4067 synthetic images...
#  -> ANGRY: Standardizing original images...
#  -> DISGUST: Generating 4055 synthetic images...
#  -> DISGUST: Standardizing original images...
#  -> FEAR: Generating 4491 synthetic images...
#  -> FEAR: Standardizing original images...
#  -> HAPPY: Standardizing original images...
#  -> NEUTRAL: Generating 2248 synthetic images...
#  -> NEUTRAL: Standardizing original images...
#  -> SAD: Generating 2790 synthetic images...
#  -> SAD: Standardizing original images...
#  -> SURPRISE: Generating 3482 synthetic images...
#  -> SURPRISE: Standardizing original images...
#
# ✅ RAF-DB Preprocessing Complete! Ready for Training.

# %%
from ultralytics import YOLO

model = YOLO('yolov8m-cls.pt')

print("🚀 Initiating YOLOv8 Training Sequence on RAF-DB...")

DATA_DIR = r'C:\Users\User\Desktop\AiAssignment\Ai-Assignment\RAF-DB'

results = model.train(
    data=DATA_DIR, 
    epochs=50, 
    imgsz=100,  
    batch=64, 
    device=0    
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8m-cls.pt to 'yolov8m-cls.pt': 100% ━━━━━━━━━━━━ 32.7MB 10.4MB/s 3.1s3.1s<0.1s5
# 🚀 Initiating YOLOv8 Training Sequence on RAF-DB...
# New https://pypi.org/project/ultralytics/8.4.38 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.37  Python-3.10.20 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=64, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=C:\Users\User\Desktop\AiAssignment\Ai-Assignment\RAF-DB, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=100, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8m-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\User\Desktop\AiAssignment\Ai-Assignment\runs\classify\train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: C:\Users\User\Desktop\AiAssignment\Ai-Assignment\RAF-DB\train... found 33404 images in 7 classes
# val: None...
# test: C:\Users\User\Desktop\AiAssignment\Ai-Assignment\RAF-DB\test... found 3068 images in 7 classes
# Overriding model.yaml nc=1000 with nc=7
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   2655744  ultralytics.nn.modules.conv.Conv             [384, 768, 3, 2]
#   8                  -1  2   7084032  ultralytics.nn.modules.block.C2f             [768, 768, 2, True]
#   9                  -1  1    994567  ultralytics.nn.modules.head.Classify         [768, 7]
# YOLOv8m-cls summary: 80 layers, 15,781,303 parameters, 15,781,303 gradients, 41.9 GFLOPs
# Transferred 228/230 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 6.4MB/s 0.8s0.8s<0.0s0.5s
# AMP: checks passed
# WARNING imgsz=[100] must be multiple of max stride 32, updating to [128]
# train: Fast image access  (ping: 0.10.0 ms, read: 9.71.7 MB/s, size: 3.4 KB)
# train: Scanning C:\Users\User\Desktop\AiAssignment\Ai-Assignment\RAF-DB\train... 33404 images, 0 corrupt: 100% ━━━━━━━━━━━━ 33404/33404  0.0s
# val: Fast image access  (ping: 0.10.0 ms, read: 7.60.8 MB/s, size: 2.6 KB)
# val: Scanning C:\Users\User\Desktop\AiAssignment\Ai-Assignment\RAF-DB\test... 3068 images, 0 corrupt: 100% ━━━━━━━━━━━━ 3068/3068  0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.01, momentum=0.9) with parameter groups 38 weight(decay=0.0), 39 weight(decay=0.0005), 39 bias(decay=0.0)
# Image sizes 128 train, 128 val
# Using 8 dataloader workers
# Logging results to C:\Users\User\Desktop\AiAssignment\Ai-Assignment\runs\classify\train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/50         1G      1.638         60        128: 100% ━━━━━━━━━━━━ 522/522 9.6it/s 54.2ss<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 35.0it/s 0.7s0.0s
#                    all      0.276      0.876
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/50      1.19G      1.038         60        128: 100% ━━━━━━━━━━━━ 522/522 10.2it/s 51.0s0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 37.8it/s 0.6s0.1s
#                    all      0.592      0.966
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/50      1.21G     0.7338         60        128: 100% ━━━━━━━━━━━━ 522/522 10.4it/s 50.4s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 38.7it/s 0.6s0.1s
#                    all      0.722      0.988
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/50      1.21G      0.574         60        128: 100% ━━━━━━━━━━━━ 522/522 10.4it/s 50.1s0.2ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 35.7it/s 0.7s0.1s
#                    all       0.75      0.988
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/50      1.24G     0.4547         60        128: 100% ━━━━━━━━━━━━ 522/522 10.6it/s 49.2s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 38.6it/s 0.6s0.1s
#                    all       0.78      0.991
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/50      1.24G     0.3874         60        128: 100% ━━━━━━━━━━━━ 522/522 10.8it/s 48.1s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 38.5it/s 0.6s0.1s
#                    all      0.792      0.991
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/50      1.24G     0.3406         60        128: 100% ━━━━━━━━━━━━ 522/522 10.4it/s 50.3s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 38.6it/s 0.6s0.1s
#                    all      0.805      0.988
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/50      1.24G     0.3096         60        128: 100% ━━━━━━━━━━━━ 522/522 10.4it/s 50.1s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 38.1it/s 0.6s0.1s
#                    all      0.798      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/50      1.24G     0.2801         60        128: 100% ━━━━━━━━━━━━ 522/522 10.6it/s 49.1s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 38.8it/s 0.6s0.1s
#                    all      0.801      0.988
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/50      1.24G     0.2635         60        128: 100% ━━━━━━━━━━━━ 522/522 10.2it/s 51.0s0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 34.5it/s 0.7s0.1s
#                    all      0.809       0.99
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/50      1.24G      0.241         60        128: 100% ━━━━━━━━━━━━ 522/522 10.1it/s 51.9s0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 35.8it/s 0.7s0.1s
#                    all      0.811       0.99
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/50      1.24G     0.2292         60        128: 100% ━━━━━━━━━━━━ 522/522 10.1it/s 51.6s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 37.1it/s 0.6s0.1s
#                    all      0.816       0.99
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/50      1.24G      0.217         60        128: 100% ━━━━━━━━━━━━ 522/522 10.2it/s 51.1s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 35.8it/s 0.7s0.1s
#                    all      0.821      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/50      1.29G     0.2087         60        128: 100% ━━━━━━━━━━━━ 522/522 10.1it/s 51.9s0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 35.2it/s 0.7s0.1s
#                    all      0.815      0.994
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/50      1.29G     0.1958         60        128: 100% ━━━━━━━━━━━━ 522/522 10.1it/s 51.9s0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 35.6it/s 0.7s0.1s
#                    all      0.824      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/50      1.29G     0.1845         60        128: 100% ━━━━━━━━━━━━ 522/522 10.0it/s 52.0s0.2ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 37.0it/s 0.6s0.1s
#                    all       0.83      0.991
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/50      1.29G     0.1822         60        128: 100% ━━━━━━━━━━━━ 522/522 10.1it/s 51.4s0.2ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 38.2it/s 0.6s0.1s
#                    all      0.829      0.994
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/50      1.29G     0.1727         60        128: 100% ━━━━━━━━━━━━ 522/522 9.9it/s 53.0ss<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 37.0it/s 0.6s0.1s
#                    all      0.828      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/50      1.29G     0.1639         60        128: 100% ━━━━━━━━━━━━ 522/522 10.0it/s 52.5s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 38.3it/s 0.6s0.1s
#                    all      0.832      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/50      1.29G     0.1565         60        128: 100% ━━━━━━━━━━━━ 522/522 10.0it/s 52.4s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 38.2it/s 0.6s0.1s
#                    all      0.827      0.992
#
#       Epoch    GPU_mem       loss  Instances       Size
#       21/50      1.29G     0.1503         60        128: 100% ━━━━━━━━━━━━ 522/522 10.1it/s 51.8s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 37.1it/s 0.6s0.1s
#                    all      0.837      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       22/50      1.29G     0.1481         60        128: 100% ━━━━━━━━━━━━ 522/522 10.2it/s 51.1s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 37.0it/s 0.6s0.1s
#                    all      0.835      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       23/50      1.29G     0.1445         60        128: 100% ━━━━━━━━━━━━ 522/522 10.1it/s 51.9s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 38.6it/s 0.6s0.1s
#                    all      0.835      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       24/50      1.29G     0.1356         60        128: 100% ━━━━━━━━━━━━ 522/522 10.2it/s 51.3s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 38.2it/s 0.6s0.1s
#                    all      0.831      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       25/50      1.29G     0.1335         60        128: 100% ━━━━━━━━━━━━ 522/522 10.1it/s 51.8s0.2ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 37.9it/s 0.6s0.1s
#                    all      0.836      0.994
#
#       Epoch    GPU_mem       loss  Instances       Size
#       26/50      1.29G     0.1193         60        128: 100% ━━━━━━━━━━━━ 522/522 10.3it/s 50.5s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 38.8it/s 0.6s0.1s
#                    all      0.838      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       27/50      1.29G      0.124         60        128: 100% ━━━━━━━━━━━━ 522/522 10.1it/s 51.9s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 35.6it/s 0.7s0.1s
#                    all      0.837      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       28/50      1.29G     0.1154         60        128: 100% ━━━━━━━━━━━━ 522/522 10.4it/s 50.2s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 38.6it/s 0.6s0.1s
#                    all      0.835      0.994
#
#       Epoch    GPU_mem       loss  Instances       Size
#       29/50      1.29G     0.1073         60        128: 100% ━━━━━━━━━━━━ 522/522 9.9it/s 52.9s<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 33.1it/s 0.7s0.1s
#                    all      0.832      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       30/50      1.29G     0.1039         60        128: 100% ━━━━━━━━━━━━ 522/522 10.0it/s 52.0s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 36.9it/s 0.7s0.1s
#                    all      0.833      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       31/50      1.29G     0.1001         60        128: 100% ━━━━━━━━━━━━ 522/522 10.2it/s 51.0s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 36.9it/s 0.6s0.1s
#                    all      0.833      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       32/50      1.29G     0.0936         60        128: 100% ━━━━━━━━━━━━ 522/522 10.0it/s 52.1s0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 36.6it/s 0.7s0.1s
#                    all      0.837      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       33/50      1.29G    0.09273         60        128: 100% ━━━━━━━━━━━━ 522/522 9.6it/s 54.1ss<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 34.7it/s 0.7s0.1s
#                    all      0.841      0.994
#
#       Epoch    GPU_mem       loss  Instances       Size
#       34/50      1.29G    0.08642         60        128: 100% ━━━━━━━━━━━━ 522/522 9.7it/s 53.8s<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 33.9it/s 0.7s0.1s
#                    all      0.842      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       35/50      1.29G    0.08036         60        128: 100% ━━━━━━━━━━━━ 522/522 9.8it/s 53.4ss<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 36.8it/s 0.7s0.1s
#                    all      0.841      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       36/50      1.29G    0.08113         60        128: 100% ━━━━━━━━━━━━ 522/522 9.9it/s 52.5ss<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 36.1it/s 0.7s0.1s
#                    all      0.842      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       37/50      1.29G    0.07161         60        128: 100% ━━━━━━━━━━━━ 522/522 10.0it/s 52.4s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 36.3it/s 0.7s0.1s
#                    all      0.842      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       38/50      1.29G    0.06473         60        128: 100% ━━━━━━━━━━━━ 522/522 10.1it/s 51.5s0.2ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 37.0it/s 0.6s0.1s
#                    all      0.841      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       39/50      1.29G    0.06385         60        128: 100% ━━━━━━━━━━━━ 522/522 10.0it/s 52.1s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 36.7it/s 0.7s0.1s
#                    all      0.839      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       40/50      1.29G    0.05841         60        128: 100% ━━━━━━━━━━━━ 522/522 10.1it/s 51.6s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 36.6it/s 0.7s0.1s
#                    all      0.842      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       41/50      1.29G    0.05458         60        128: 100% ━━━━━━━━━━━━ 522/522 9.5it/s 55.0s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 36.8it/s 0.7s0.1s
#                    all      0.841      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       42/50      1.29G    0.04817         60        128: 100% ━━━━━━━━━━━━ 522/522 10.0it/s 52.3s0.2ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 36.8it/s 0.7s0.1s
#                    all      0.842      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       43/50      1.29G    0.04483         60        128: 100% ━━━━━━━━━━━━ 522/522 10.0it/s 52.4s0.2ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 36.7it/s 0.7s0.1s
#                    all      0.842      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       44/50      1.29G    0.04291         60        128: 100% ━━━━━━━━━━━━ 522/522 10.1it/s 51.5s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 36.9it/s 0.7s0.1s
#                    all      0.842      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       45/50      1.29G    0.03785         60        128: 100% ━━━━━━━━━━━━ 522/522 10.1it/s 51.8s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 38.0it/s 0.6s0.1s
#                    all      0.842      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       46/50      1.29G    0.03648         60        128: 100% ━━━━━━━━━━━━ 522/522 10.0it/s 52.3s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 35.9it/s 0.7s0.1s
#                    all      0.842      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       47/50      1.29G    0.03569         60        128: 100% ━━━━━━━━━━━━ 522/522 9.9it/s 52.9s<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 38.1it/s 0.6s0.1s
#                    all      0.841      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       48/50      1.29G    0.03482         60        128: 100% ━━━━━━━━━━━━ 522/522 9.9it/s 53.0s<0.2ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 38.2it/s 0.6s0.1s
#                    all      0.841      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       49/50      1.29G    0.02894         60        128: 100% ━━━━━━━━━━━━ 522/522 9.8it/s 53.0s<0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 38.2it/s 0.6s0.1s
#                    all      0.843      0.993
#
#       Epoch    GPU_mem       loss  Instances       Size
#       50/50      1.29G    0.03001         60        128: 100% ━━━━━━━━━━━━ 522/522 10.1it/s 51.5s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 38.3it/s 0.6s0.1s
#                    all      0.844      0.993
#
# 50 epochs completed in 0.740 hours.
# Optimizer stripped from C:\Users\User\Desktop\AiAssignment\Ai-Assignment\runs\classify\train\weights\last.pt, 31.7MB
# Optimizer stripped from C:\Users\User\Desktop\AiAssignment\Ai-Assignment\runs\classify\train\weights\best.pt, 31.7MB
#
# Validating C:\Users\User\Desktop\AiAssignment\Ai-Assignment\runs\classify\train\weights\best.pt...
# Ultralytics 8.4.37  Python-3.10.20 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# YOLOv8m-cls summary (fused): 42 layers, 15,771,623 parameters, 0 gradients, 41.6 GFLOPs
# WARNING Dataset 'split=val' not found, using 'split=test' instead.
# train: C:\Users\User\Desktop\AiAssignment\Ai-Assignment\RAF-DB\train... found 33404 images in 7 classes
# val: C:\Users\User\Desktop\AiAssignment\Ai-Assignment\RAF-DB\test... found 3068 images in 7 classes
# test: C:\Users\User\Desktop\AiAssignment\Ai-Assignment\RAF-DB\test... found 3068 images in 7 classes
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 24/24 39.8it/s 0.6s0.2s
#                    all      0.844      0.993
# Speed: 0.0ms preprocess, 0.2ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to C:\Users\User\Desktop\AiAssignment\Ai-Assignment\runs\classify\train

# %%
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from ultralytics import YOLO
from sklearn.metrics import classification_report, confusion_matrix

# --- File path---
MODEL_PATH = r'C:\Users\User\Desktop\AiAssignment\Ai-Assignment\runs\classify\train\weights\best.pt'
TEST_DIR = r'C:\Users\clogg\Desktop\School Github Repos\Ai-Assignment\RAF-DB\test'

model = YOLO(MODEL_PATH)
class_names = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

y_true = []
y_pred = []

for emotion in class_names:
    folder_path = os.path.join(TEST_DIR, emotion)
    if not os.path.isdir(folder_path): continue
        
    for img_path in glob.glob(os.path.join(folder_path, '*.jpg')):
        results = model(img_path, verbose=False)
        pred_class = results[0].names[results[0].probs.top1]
        
        y_true.append(emotion)
        y_pred.append(pred_class)

print("\n" + "="*50)
print("📊 CLASSIFICATION REPORT")
print("="*50)
report = classification_report(y_true, y_pred, target_names=class_names)
print(report)

with open("classification_report.txt", "w") as text_file:
    text_file.write(report)

plt.figure(figsize=(10, 8))
sns.heatmap(confusion_matrix(y_true, y_pred, labels=class_names), annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('YOLOv8 RAF-DB Confusion Matrix')
plt.ylabel('Actual Emotion')
plt.xlabel('Predicted Emotion')
plt.savefig('custom_confusion_matrix.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 13
#      10 MODEL_PATH = r'C:\Users\clogg\Desktop\School Github Repos\Ai-Assignment\runs\classify\train3\weights\best.pt'
#      11 TEST_DIR = r'C:\Users\clogg\Desktop\School Github Repos\Ai-Assignment\RAF-DB\test'
# ---> 13 model = YOLO(MODEL_PATH)
#      14 class_names = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
#      16 y_true = []
#
# File ~\anaconda3\envs\fer-env\lib\site-packages\ultralytics\models\yolo\model.py:76, in YOLO.__init__(self, model, task, verbose)
#      73     self.__dict__ = new_instance.__dict__
#      74 else:
#      75     # Continue with default YOLO initialization
# ---> 76     super().__init__(model=model, task=task, verbose=verbose)
#      77     if hasattr(self.model, "model") and "RTDETR" in self.model.model[-1]._get_name():  # if RTDETR head
#      78         from ultralytics import RTDETR
#
# File ~\anaconda3\envs\fer-env\lib\site-packages\ultralytics\engine\model.py:144, in Model.__init__(self, model, task, verbose)
#     142     self._new(model, task=task, verbose=verbose)
#     143 else:
# --> 144     self._load(model, task=task)
#     146 # Delete super().training for accessing self.model.training
#     147 del self.training
#
# File ~\anaconda3\envs\fer-env\lib\site-packages\ultralytics\engine\model.py:283, in Model._load(self, weights, task)
#     280 weights = checks.check_model_file_from_stem(weights)  # add suffix, i.e. yolo26 -> yolo26n.pt
#     282 if str(weights).rpartition(".")[-1] == "pt":
# --> 283     self.model, self.ckpt = load_checkpoint(weights)
#     284     self.task = self.model.task
#     285     self.overrides = self.model.args = self._reset_ckpt_args(self.model.args)
#
# File ~\anaconda3\envs\fer-env\lib\site-packages\ultralytics\nn\tasks.py:1515, in load_checkpoint(weight, device, inplace, fuse)
#    1502 def load_checkpoint(weight, device=None, inplace=True, fuse=False):
#    1503     """Load single model weights.
#    1504
#    1505     Args:
#    (...)
#    1513         (dict): Model checkpoint dictionary.
#    1514     """
# -> 1515     ckpt, weight = torch_safe_load(weight)  # load ckpt
#    1516     args = {**DEFAULT_CFG_DICT, **(ckpt.get("train_args", {}))}  # combine model and default args, preferring model args
#    1517     model = (ckpt.get("ema") or ckpt["model"]).float()  # FP32 model
#
# File ~\anaconda3\envs\fer-env\lib\site-packages\ultralytics\nn\tasks.py:1463, in torch_safe_load(weight, safe_only)
#    1461                 ckpt = torch_load(f, pickle_module=safe_pickle)
#    1462         else:
# -> 1463             ckpt = torch_load(file, map_location="cpu")
#    1465 except ModuleNotFoundError as e:  # e.name is missing module name
#    1466     if e.name == "models":
#
# File ~\anaconda3\envs\fer-env\lib\site-packages\ultralytics\utils\patches.py:178, in torch_load(*args, **kwargs)
#     175 if TORCH_1_13 and "weights_only" not in kwargs:
#     176     kwargs["weights_only"] = False
# --> 178 return torch.load(*args, **kwargs)
#
# File ~\anaconda3\envs\fer-env\lib\site-packages\torch\serialization.py:1479, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1476 if "encoding" not in pickle_load_args.keys():
#    1477     pickle_load_args["encoding"] = "utf-8"
# -> 1479 with _open_file_like(f, "rb") as opened_file:
#    1480     if _is_zipfile(opened_file):
#    1481         # The zipfile reader is going to advance the current file position.
#    1482         # If we want to actually tail call to torch.jit.load, we need to
#    1483         # reset back to the original position.
#    1484         orig_position = opened_file.tell()
#
# File ~\anaconda3\envs\fer-env\lib\site-packages\torch\serialization.py:759, in _open_file_like(name_or_buffer, mode)
#     757 def _open_file_like(name_or_buffer: FileLike, mode: str) -> _opener[IO[bytes]]:
#     758     if _is_path(name_or_buffer):
# --> 759         return _open_file(name_or_buffer, mode)
#     760     else:
#     761         if "w" in mode:
#
# File ~\anaconda3\envs\fer-env\lib\site-packages\torch\serialization.py:740, in _open_file.__init__(self, name, mode)
#     739 def __init__(self, name: Union[str, os.PathLike[str]], mode: str) -> None:
# --> 740     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\clogg\\Desktop\\School Github Repos\\Ai-Assignment\\runs\\classify\\train3\\weights\\best.pt'
